# %% [markdown]
# ### Warming up

# %%
#Warming up
sum = 0
for i in range(1000):
    if (i % 3 == 0) | (i % 5 == 0):
        sum = sum + i

print(sum)
# Out:
# 233168

# %%
result = sum([i for i in range(1000) if i % 3 == 0 or i % 5 == 0])
result
# Out:
# 233168

# %%
import numpy as np
import pandas as pd

data = {
    'id' : [1,2,3], 
    'name' : ['Choi', 'Lee', 'Kim'], 
    'age' : [10, 20, 30], 
    'assets' : [150.4, 123.4, 88.88], 
    'job' : ['student', 'CEO', 'Dad']
}

df = pd.DataFrame(data) 
#df = pd.DataFrame(data, columns = [~~~], index = [~~~]) 

df.index = df['id']

df['hobby'] = 'reading books'

res = {1 : 'Bundang', 2 : 'Seoul', 3: 'Incheon'}
res_se = pd.Series(res)
res_se


df['res'] = res_se

del df['id']
df
# Out:
#     name  age  assets      job          hobby      res
# id
# 1   Choi   10  150.40  student  reading books  Bundang
# 2    Lee   20  123.40      CEO  reading books    Seoul
# 3    Kim   30   88.88      Dad  reading books  Incheon

# %%
del df['hobby']
df.loc[4] = ['Hwang', 40, 100, 'Prog', 'Gangnam']
df
# Out:
#      name  age  assets      job      res
# id
# 1    Choi   10  150.40  student  Bundang
# 2     Lee   20  123.40      CEO    Seoul
# 3     Kim   30   88.88      Dad  Incheon
# 4   Hwang   40  100.00     Prog  Gangnam

# %%
df.values
# Out:
# array([['Choi', 10, 150.4, 'student', 'Bundang'],
#        ['Lee', 20, 123.4, 'CEO', 'Seoul'],
#        ['Kim', 30, 88.88, 'Dad', 'Incheon'],
#        ['Hwang', 40, 100.0, 'Prog', 'Gangnam']], dtype=object)

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
df.T
# Out:
# id            1      2        3        4
# name       Choi    Lee      Kim    Hwang
# age          10     20       30       40
# assets    150.4  123.4    88.88      100
# job     student    CEO      Dad     Prog
# res     Bundang  Seoul  Incheon  Gangnam

# %%
df.loc[1]['name']
# Out:
# 'Choi'

# %%
import pandas as pd 

se1 = pd.Series(range(1,10))
se2 = se1 * 2
se3 = se1 * 3

# %%
dict1 = {1:se1, 2:se2, 3:se3}
pf = pd.DataFrame(dict1)
pf
# Out:
#    1   2   3
# 0  1   2   3
# 1  2   4   6
# 2  3   6   9
# 3  4   8  12
# 4  5  10  15
# 5  6  12  18
# 6  7  14  21
# 7  8  16  24
# 8  9  18  27

# %%
number_hangul = '일이삼사오육칠팔구'


pf.index = [i for i in number_hangul]
pf
# Out:
#    1   2   3
# 일  1   2   3
# 이  2   4   6
# 삼  3   6   9
# 사  4   8  12
# 오  5  10  15
# 육  6  12  18
# 칠  7  14  21
# 팔  8  16  24
# 구  9  18  27

# %%
se4 = se1 * 4 
se4.index = pf.index 
pf[4] = se4
pf
# Out:
#    1   2   3   4
# 일  1   2   3   4
# 이  2   4   6   8
# 삼  3   6   9  12
# 사  4   8  12  16
# 오  5  10  15  20
# 육  6  12  18  24
# 칠  7  14  21  28
# 팔  8  16  24  32
# 구  9  18  27  36

# %%
pf = pf.rename(columns = {1:11})
pf
# Out:
#    11  2   3   4
# 일  11   2   3   4
# 이  22   4   6   8
# 삼  33   6   9  12
# 사  44   8  12  16
# 오  55  10  15  20
# 육  66  12  18  24
# 칠  77  14  21  28
# 팔  88  16  24  32
# 구  99  18  27  36

# %%
pf[1].columns = 11
pf
# Out:
#     1   2   3   4
# 일  11   2   3   4
# 이  22   4   6   8
# 삼  33   6   9  12
# 사  44   8  12  16
# 오  55  10  15  20
# 육  66  12  18  24
# 칠  77  14  21  28
# 팔  88  16  24  32
# 구  99  18  27  36

# %%
pf.T
# Out:
#     일   이   삼   사   오   육   칠   팔   구
# 1  11  22  33  44  55  66  77  88  99
# 2   2   4   6   8  10  12  14  16  18
# 3   3   6   9  12  15  18  21  24  27
# 4   4   8  12  16  20  24  28  32  36

# %%
pf.drop(['오', '칠'])
# Out:
#     1   2   3   4
# 일  11   2   3   4
# 이  22   4   6   8
# 삼  33   6   9  12
# 사  44   8  12  16
# 육  66  12  18  24
# 팔  88  16  24  32
# 구  99  18  27  36

# %% [markdown]
# ### Pandas IO 도구들

# %%
import pandas as pd 
df = pd.read_csv('csv_test.csv')
df
# Out:
#    Unnamed: 0  col1 col2  col3
# 0           0     a    b     1
# 1           1     a    b     2
# 2           2  col1    d     3

# %%
df.to_csv('csv_test2.csv')

# %%
df = pd.read_excel('a.xlsx', sheet='a')
df
# Out:
#      name     Age       Status
# 0    Ally      21       Single
# 1  Daniel      32       Single
# 2    John     N/A      Married
# 3   Baker      25       Single
# 4    Josh     N/A      Married

# %%
df.to_excel('a2.xlsx')

# %%
url = 'https://www.fdic.gov/bank/individual/failed/banklist.html'
dfs = pd.read_html(url)
dfs
# Out:
# [                                             Bank Name                City  \
#  0                  Washington Federal Bank for Savings             Chicago
#  1      The Farmers and Merchants State Bank of Argonia             Argonia
#  2                                  Fayette County Bank          Saint Elmo
#  3    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
#  4                                       First NBC Bank         New Orleans
#  5                                        Proficio Bank  Cottonwood Heights
#  6                        Seaway Bank and Trust Company             Chicago
#  7                               Harvest Community Bank          Pennsville
#  8                                          Allied Bank            Mulberry
#  9                         The Woodbury Banking Company            Woodbury
#  10                              First CornerStone Bank     King of Prussia
# ...

# %%
import numpy as np
from sklearn import datasets


Iris = datasets.load_iris()
 
Iris_Data = pd.DataFrame(data= np.c_[Iris['data'], Iris['target']], columns= Iris['feature_names'] + ['target'])
Iris_Data['target'] = Iris_Data['target'].map({0: "setosa", 1: "versicolor", 2: "virginica"})

Iris_Data[:10]
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
# 5  setosa
# 6  setosa
# 7  setosa
# 8  setosa
# 9  setosa

# %%
import pymysql 
import pandas as pd 

conn = pymysql.connect(host='localhost', user='root', password='apmsetup', db='mysql', charset='utf8')
sql = "select * from user"

pd.read_sql_query(sql, conn)
# Out:
#         Host        User                                   Password  \
# 0  localhost        root  *B50EC7C3542297D602BAA80DDC52A05AB89CF827
# 1  localhost  phpmyadmin  *387B36D01A7C5EC3AF24E860C269DAA274EF94EF
#
#   Select_priv Insert_priv Update_priv Delete_priv Create_priv Drop_priv  \
# 0           Y           Y           Y           Y           Y         Y
# 1           N           N           N           N           N         N
#
#   Reload_priv         ...          Event_priv Trigger_priv ssl_type  \
# 0           Y         ...                   Y            Y
# 1           N         ...                   N            N
#
#   ssl_cipher x509_issuer x509_subject max_questions max_updates  \
# 0        b''         b''          b''             0           0
# 1        b''         b''          b''             0           0
#
#   max_connections max_user_connections
# 0               0                    0
# 1               0                    0
#
# [2 rows x 39 columns]

# %%
data = {
    'id' : [1,2,3], 
    'name' : ['Choi', 'Lee', 'Kim'], 
    'age' : [10, 20, 30], 
    'assets' : [150.4, 123.4, 88.88], 
    'job' : ['student', 'CEO', 'Dad']
}

df = pd.DataFrame(data) 
#df = pd.DataFrame(data, columns = [~~~], index = [~~~]) 

df.sort_index()
# Out:
#    id  name  age  assets      job
# 0   1  Choi   10  150.40  student
# 1   2   Lee   20  123.40      CEO
# 2   3   Kim   30   88.88      Dad

# %%
df.sort_index(axis=1)
# Out:
#    age  assets  id      job  name
# 0   10  150.40   1  student  Choi
# 1   20  123.40   2      CEO   Lee
# 2   30   88.88   3      Dad   Kim

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#    name      job  id  assets  age
# 0  Choi  student   1  150.40   10
# 1   Lee      CEO   2  123.40   20
# 2   Kim      Dad   3   88.88   30

# %%
df.sort_values(by=['job', 'age'], ascending=True)
# Out:
#    id  name  age  assets      job
# 1   2   Lee   20  123.40      CEO
# 2   3   Kim   30   88.88      Dad
# 0   1  Choi   10  150.40  student

# %%
import pandas as pd

se = pd.Series(range(1, 10))
se2 = se * 9
se2
se2.index = range(9, 0, -1)

se2
# Out:
# 9     9
# 8    18
# 7    27
# 6    36
# 5    45
# 4    54
# 3    63
# 2    72
# 1    81
# dtype: int64

# %%
se7 = se * 7 
se8 = se * 9

se2 = pd.DataFrame(se2)

se7.index = se2.index
se8.index = se2.index

se2[1] = se7
se2[2] = se8 
se2
# Out:
#     0   1   2
# 9   9   7   9
# 8  18  14  18
# 7  27  21  27
# 6  36  28  36
# 5  45  35  45
# 4  54  42  54
# 3  63  49  63
# 2  72  56  72
# 1  81  63  81

# %%
se2.sort_index(ascending=True)
# Out:
#     0   1   2
# 1  81  63  81
# 2  72  56  72
# 3  63  49  63
# 4  54  42  54
# 5  45  35  45
# 6  36  28  36
# 7  27  21  27
# 8  18  14  18
# 9   9   7   9

# %%
index = list(range(1,10))[::-1]
index
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
se = pd.Series(range(1, 10))
se7 = se * 7 
se8 = se * 9
se9 = se * 9
dict1 = { "7단": se7, 
        "8단": se8, 
         "9단": se9
        }
df2 = pd.DataFrame(dict1)
df2
# Out:
#    7단  8단  9단
# 0   7   9   9
# 1  14  18  18
# 2  21  27  27
# 3  28  36  36
# 4  35  45  45
# 5  42  54  54
# 6  49  63  63
# 7  56  72  72
# 8  63  81  81

# %%
df2.sort_index(axis=1, ascending=False)
# Out:
#    9단  8단  7단
# 0   9   9   7
# 1  18  18  14
# 2  27  27  21
# 3  36  36  28
# 4  45  45  35
# 5  54  54  42
# 6  63  63  49
# 7  72  72  56
# 8  81  81  63
